# %% [markdown]
# ## Espectro de Absorción de la Clorofila

# %% [markdown]
# ### Espinaca

# %%
using Plots
gr()
# Out:
# Plots.GRBackend()

# %%
abs_clorofila=[.619,.49,.281,.194,.144,.108,.245,0.058,0.052,0.046,0.04,0.042,.135,-0.049,-0.042,.205,.203,.198,.193,.193,.198,.202,.203,.205,.192,.195,.200,.197,.209,.212,.218,.117,.110,.125,.233,.234,.236,.229,.223,.212,.218,.238,.262,.298,.338,.386,.427,.434,.399,.324,.247,0.074,0.041,0.024]
λ=[]
xi=480
for i in 1:length(abs_clorofila)
    push!(λ,xi)
    xi+=4
end

plot(λ,abs_clorofila,c="green",title="Espectro de Absorción de la Clorofila",label="espinaca")
scatter!([λ],[abs_clorofila],c="blue",xlabel="Longitud de Onda [nm]",ylabel="Absorción Relativa",label="")
scatter!([536],[-0.042],c="red",label="")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip5800">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5800)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip5801">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5800)" points="
# 48.2225,360.121 580.315,360.121 580.315,31.4961 48.2225,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip5802">
#     <rect x="48" y="31" width="533" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip5802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   110.638,360.121 110.638,31.4961
#   "/>
# ...

# %%
abs_clorofila=[.439,.411,.394,.395,.401,.498,.510,.351,.299,.254,.201,.146,.105,0.084,0.066,0.055,0.048,0.044,0.04,0.039,0.039,0.048,0.051,0.051,0.056,0.051,0.050,0.052,0.052,0.054,0.058,0.061,0.065,0.069,0.073,0.077,0.08,0.083,0.086,0.09,0.094,0.097,0.099,0.098,0.097,0.094,0.095,0.097,.108,.125,.147,.182,.218,.263,.301,.308,.27,.204,.129,0.075,0.047,0.030]
λ=[]
xi=448
for i in 1:length(abs_clorofila)
    push!(λ,xi)
    xi+=4
end

plot(λ,abs_clorofila,c="green",title="Espectro de Absorción de la Clorofila",label="Espinaca")
scatter!([λ],[abs_clorofila],c="green",xlabel="Longitud de Onda [nm]",ylabel="Absorción Relativa",label="")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip2800">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2800)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip2801">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2800)" points="
# 48.2225,360.121 580.315,360.121 580.315,31.4961 48.2225,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip2802">
#     <rect x="48" y="31" width="533" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip2802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   67.3963,360.121 67.3963,31.4961
#   "/>
# ...

# %%
abs_clorofila1=[.417,.387,.371,.371,.376,.379,.363,.328,.276,.241,.195,.147,.117,0.097,0.083,0.071,0.066,0.06,0.058,0.055,0.056,0.06,0.061,0.063,0.062,0.061,0.061,0.061,0.063,0.064,0.067,0.069,0.071,0.073,0.076,0.077,0.078,0.082,0.085,0.089,0.09,0.093,0.093,0.093,0.09,0.089,0.087,0.091,0.098,.115,.133,.16,.193,.223,.228+0.018,.258,.234,.181,.116,0.072,0.045,0.030]
λ=[]
xi=448
for i in 1:length(abs_clorofila)
    push!(λ,xi)
    xi+=4
end

plot(λ,abs_clorofila1,c="green",title="Espectro de Absorción de la Clorofila",label="Espinaca")
scatter!([λ],[abs_clorofila1],c="green",xlabel="Longitud de Onda [nm]",ylabel="Absorción Relativa",label="")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip3000">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3000)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip3001">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3000)" points="
# 48.2225,360.121 580.315,360.121 580.315,31.4961 48.2225,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip3002">
#     <rect x="48" y="31" width="533" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip3002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   67.3963,360.121 67.3963,31.4961
#   "/>
# ...

# %%
abs_clorofila_P=[1.305,1.255,1.235,1.235,1.245,1.235,1.185,1.062,0.896,0.752,0.588,0.416,0.301,0.216,0.158,0.123,0.103,0.082,0.078,0.075,0.074,0.079,0.082,0.086,0.089,0.087,0.088,0.090,0.096,0.103,0.109,0.119,0.128,0.133,0.144,0.151,0.159,0.168,0.178,0.191,0.202,0.211,0.219,0.221,0.222,0.222,0.227,0.246,0.288,0.347,0.412,0.486,0.564,0.648,0.704,0.696,0.583,0.402,0.266,0.149,0.090,0.056]
λ=[]
xi=448
for i in 1:length(abs_clorofila_P)
    push!(λ,xi)
    xi+=4
end

plot(λ,abs_clorofila_P,c="blue",title="Espectro de Absorción de la Clorofila",label="Pepino")
scatter!([λ],[abs_clorofila_P],c="blue",xlabel="Longitud de Onda [nm]",ylabel="Absorción Relativa",label="")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip3200">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3200)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip3201">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3200)" points="
# 54.9131,360.121 580.315,360.121 580.315,31.4961 54.9131,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip3202">
#     <rect x="54" y="31" width="526" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.8458,360.121 73.8458,31.4961
#   "/>
# ...

# %%
abs_clorofila_N=[0.065,0.061,0.06,0.057,0.056,0.056,0.053,0.048,0.044,0.045,0.031,0.019,0.018,0.021,0.022,0.02,0.02,0.019,0.015,0.015,0.016,0.016,0.016,0.016,0.016,0.015,0.015,0.014,0.014,0.014,0.014,0.014,0.014,0.014,0.013,0.014,0.015,0.015,0.015,0.016,0.018,0.017,0.018,0.018,0.017,0.016,0.017,0.018,0.02,0.021,0.023,0.027,0.031,0.035,0.039,0.04,0.037,0.029,0.023,0.017,0.014,0.012]
λ=[]
xi=448
for i in 1:length(abs_clorofila_N)
    push!(λ,xi)
    xi+=4
end

plot(λ,abs_clorofila_N,c="orange",title="Espectro de Absorción de la Clorofila",label="Nopal")
scatter!([λ],[abs_clorofila_N],c="orange",xlabel="Longitud de Onda [nm]",ylabel="Absorción Relativa",label="")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip3400">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3400)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip3401">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3400)" points="
# 54.9131,360.121 580.315,360.121 580.315,31.4961 54.9131,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip3402">
#     <rect x="54" y="31" width="526" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   73.8458,360.121 73.8458,31.4961
#   "/>
# ...

# %%
λ=[]
xi=448
for i in 1:length(abs_clorofila_N)
    push!(λ,xi)
    xi+=4
end

plot(λ,abs_clorofila1,c="green",title="Espectro de Absorción de la Clorofila",label="Espinaca")
scatter!([λ],[abs_clorofila1],c="green",xlabel="Longitud de Onda [nm]",ylabel="Absorción Relativa",label="")

plot!(λ,abs_clorofila_P,c="blue",label="Pepino")
scatter!([λ],[abs_clorofila_P],c="blue",label="")

plot!(λ,abs_clorofila_N,c="orange",label="Nopal")
scatter!([λ],[abs_clorofila_N],c="orange",label="")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip3600">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3600)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip3601">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3600)" points="
# 48.2225,360.121 580.315,360.121 580.315,31.4961 48.2225,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip3602">
#     <rect x="48" y="31" width="533" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip3602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   67.3963,360.121 67.3963,31.4961
#   "/>
# ...

# %%
λ=[]
xi=448
for i in 1:length(abs_clorofila_N)
    push!(λ,xi)
    xi+=4
end
a=maximum(abs_clorofila1)
b=maximum(abs_clorofila_N)
c=maximum(abs_clorofila_P)

for i in 1:length(abs_clorofila1)
    abs_clorofila1[i]=abs_clorofila1[i]/a
    abs_clorofila_N[i]=abs_clorofila_N[i]/b
    abs_clorofila_P[i]=abs_clorofila_P[i]/c
end

plot(λ,abs_clorofila1,c="green",title="Espectro de Absorción Normalizado",label="Espinaca")
scatter!([λ],[abs_clorofila1],c="green",xlabel="Longitud de Onda [nm]",ylabel="Absorción Relativa",label="")

plot!(λ,abs_clorofila_P,c="blue",label="Pepino")
scatter!([λ],[abs_clorofila_P],c="blue",label="")

plot!(λ,abs_clorofila_N,c="orange",label="Nopal")
scatter!([λ],[abs_clorofila_N],c="orange",label="")

#savefig("AbsorcionNormalizado.png")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip4100">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4100)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip4101">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4100)" points="
# 48.2225,360.121 580.315,360.121 580.315,31.4961 48.2225,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip4102">
#     <rect x="48" y="31" width="533" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip4102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   67.3963,360.121 67.3963,31.4961
#   "/>
# ...
